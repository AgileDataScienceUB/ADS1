# %%
import pandas as pd

db = pd.read_json(path_or_buf="data/titles.json")

# %%
db = db.T

# %%
db.head()
# Out:
#                                              c  i  \
# 'Brandade'                                  30  0
# 'Dragon prawn' noodles                      30  1
# 'Firecracker' prawns                        30  0
# 'Guilt-free gourmet' sticky toffee pudding  60  1
# 'Lion head' meatballs                       30  1
#
#                                                                                             l  \
# 'Brandade'                                  [ 2 tbsp olive oil,  1 clove garlic,  15g/½oz ...
# 'Dragon prawn' noodles                      [ 650g/1lb 6oz live lobster,  2 tbsp groundnut...
# 'Firecracker' prawns                        [ 12 large prawns, in the shell,  ¼ tsp garlic...
# 'Guilt-free gourmet' sticky toffee pudding  [ 225g/8oz dates, pitted and chopped,  200ml/7...
# 'Lion head' meatballs                       [ 500g/1lb 2oz beef mince,  4 garlic cloves, f...
#
#                                              p          s  v
# ...

# %%
db[:]
# Out:
#                                                       c  i  \
# 'Brandade'                                           30  0
# 'Dragon prawn' noodles                               30  1
# 'Firecracker' prawns                                 30  0
# 'Guilt-free gourmet' sticky toffee pudding           60  1
# 'Lion head' meatballs                                30  1
# 'Mr Carrot' on creamed carrot                        10  0
# 'Nduja sausage and sheeps’ cheese pizza              10  1
# 'No butter' brandy butter                           NaN  0
# 'Scampi', chips and tartare sauce                    30  0
# 'Skinnylicious' vanilla cake                        120  0
# 'Tex-Mex' chilli beans                               30  0
# 'Westie' shortbread                                  60  0
# 15 minute pasta                                      30  1
# 2-hour Christmas dinner                             120  1
# 3D biscuits                                         120  1
# ...

# %%
db1=db[:1000]

# %%
db1
# Out:
#                                                       c  i  \
# 'Brandade'                                           30  0
# 'Dragon prawn' noodles                               30  1
# 'Firecracker' prawns                                 30  0
# 'Guilt-free gourmet' sticky toffee pudding           60  1
# 'Lion head' meatballs                                30  1
# 'Mr Carrot' on creamed carrot                        10  0
# 'Nduja sausage and sheeps’ cheese pizza              10  1
# 'No butter' brandy butter                           NaN  0
# 'Scampi', chips and tartare sauce                    30  0
# 'Skinnylicious' vanilla cake                        120  0
# 'Tex-Mex' chilli beans                               30  0
# 'Westie' shortbread                                  60  0
# 15 minute pasta                                      30  1
# 2-hour Christmas dinner                             120  1
# 3D biscuits                                         120  1
# ...

# %%
typefood3=['Britsh','','Italian','Italian','Strange','Strange','Strange','Jamaican','Easy meat','Easy meat',
'Easy meat','Easy meat','Easy meat','Easy meat','Turkish','Chinese','Chinese','Scottish','French','French',
'British','British','Universal','Italian','Italian','Czech','Mexican','Mexican','British','Italian','Indian',
'Indian','Chinese','Thai','Indian','Argentinian','Mexican','Strange','French','Japanese','French','Portuguese'
,'French','Japanese fusion','French','Hungarian','Hungarian','French','Irish','Strange','Arabian','Turkis',
'Arabian','Indian','British','Vietnamise','French','Italian','Italian','Indonesian','Indonesian','Indonesian'
,'BBq meat','Italian','Chinese','British','Australian','Universal','Universal','Universal','Chinese','French'
,'Chinese','Chinese','Chinese','Chonese','Chinese','Russian','Russian','Russian','British','Japanese','Italian'
,'Mexican','French','Italian','Italian','Italian','Moroccan','Mexican','Universal','British','Irish','French'
,'British','Scottish','British','Welsh','Welsh','British','Irish','Irish','British','British','Scottish',
'Irish','British','Seafood','British','British','French','Irish','Swiss','American','Strange','Italian','Italian',
'Finnish','Strange','Italian','Bad idea','Salad','Bad idea','Salad','Salad','Strange','Strange','Bad idea',
'French','French','British','Greek','French','Greek','Mediterranean','Mediterranean','Mediterranean','Japanese',
'Mediterranean','Mediterranean','Mediterranean','Belgian','Italian','British','Bengali','Bengali','Bengali'
,'Bengali','American','American','American','American','Dessert','French','Italian','Indian','Indian','Irish',
'Universal','Polish','Dessert','Australian','Italian','Breakfast','Italian','Italian','Italian','British'
,'German','German','German','German','German','German','German','German','German','German','German','Dessert'
'Dessert','Dessert','Strange','British','Japanese','Irish','Scottish','Scottish','Dessert','Italian','British'
,'Japanese','Indian','Italian','','Irish','Chinese','Chinese','Strange','British','British'
'British','British','British','British','British','Mediterranean','Italian','British','Scottish','British',
'British','Juice','Dessert','British','British','Dessert','Italian','Dessert','Danish','Danish','Danish',
'Dessert','Dessert','Danish','Swiss','Italian','Dessert','Hard dessert','Dessert','Irish','Seafood','Swedish'
,'Swedish','Russian','Russian','Russian','Russian','Especial dessert','Especial dessert','Coctel','Coctel',
'Russian','Welsh','French','French','French','French','French','French','Universal','Italian','French','French',
'Italian','French','French','French','French','French','Danish','dessert','Dessert','Italian Dessert','Mediterranean'
,'Dessert','Dessert','Dessert','Italian dessert','Italian dessert','British dessert','British','Dessert','Dessert',
'Dessert','Universal dessert','French dessert','Strange dessert','Universal dessert','Dessert','Juice','Dessert',
'British dessert','Universal dessert','Universal dessert','South African','French','French','British','Fusion'
,'BBC innovation','BBC innovation','Dessert','Mediterranean','Italian','Italian','Italian','Italian','Italian',
'Italian','Italian','Italian','Indian','Indian','Indian','Indian','French','Indian','Special meals','Special meals'
,'British','British','Turkish','Italian','Russian','Russian','Ameriacn','French','French','French','American',
'American','American','American','Mediterranean','Special meals','Irish','Irish','Italian','British','British',
'Moroccan','French','BBq meat','british','Universal','Universal','Irish','Irish','British','French','French'
,'British','American','Italian','British','American','British','French','Italian','American','French','French'
,'French','Italian','Seafood','Irish','India','India','India','India','India','Indian','Indian','Indian','Greek',
'Mediterranean','Mediterranean','French','Autralian','Autralian','French','British','British',
'French','FRench','French','Mix','French','French','Universal','French','Mediterranean','American','British',
'American','Strange','American','Seafood','American','Dessert','British','British','British','Dessert','Sauce',
'British','Bitish','British','British','British','British']

# %%
len(typefood3)
# Out:
# 400

# %%
=['','','','','','','','','','','','','','','','','','','','']
# Out:
#   File "<ipython-input-134-520d98721c69>", line 1
#     =['','','','','','','','','','','','','','','','','','','','']
#     ^
# SyntaxError: invalid syntax

# %%
typefood2=['italian','thai','thai','english','','','Italian','','','','Mexican','','Italian','','','','','','',\
 'French','Mediterranean','Scottish','','Canadian','','English','German','Chinese','Thai','Italian','Italian',
 '','Japanese','Japansese','Albanian','Mexican','','English','American','American','American','Indian','',
    '','','','Indian','','English','','English','','','','','','','','','','','','Italian','English','Italian',
   'Italian','Italian','Italian','','American','American','American','American','American','American','French',
'','Indian','Indian','','','Mediterranean','Mediterranean','Mediterranean','American','American','Swedish',
'Italian','English','Italian','','','','','','','','','','','','','','','','','','','','','','','','','',''
          ,'','','','','','','','','','','','','','','','','','','','','','','','','','','','','','','','',
          '','','','','','','','','','American','','','','','','','Italian','','','Italian','French','French',
'','French','French','','','','Arabian','Italian','Italian','Italian','French','Scottish','Scottish','Scottish'
,'Scottish','English','French','English','English','English','Indian','Indian','Moroccan','','Finish','Italian'
    ,'Vietnamise','Italian','','Italian','Italian','Italian','','French','Italian','Mediterranean','Italian',
'Italian','French','French','Asian','Asian','Asian','Asian','Asian','Asian','Asian','Asian','Asian','Asian',
'Asian','Asian','Asian','Asian','Asian','Asian','Asian','Asian','Asian','Asian','Italian','','Italian'
,'Mediterranean','Italian','American','Asian','Mediterranean','Mediterranean','English','','French','Finish',
'Italian','Mediterranean','Mediterranean','German','Ducth','Italian','English','English','English','Dutch'
,'Mexican','American','American','French','Greek','Italian','French','French','Greek','Italian','Italian',
'Italian','Italian','Chinese','French','','Greek','Indian','','','French','Moroccan','Greek','','Italian','Greek',
'Thai','Italian','','Italian','Moroccan','English','English','English','Greek','Italian','American','Italian'
,'','','','','','Hawaian','Indonesian','Mexican','Spanish','American','American','American','','American',
'American','American','American','Armenian','Armenian','Armenian','Mediterranean','Mediterranean','Italian'
,'Mediterranean','Mediterranean','','','Mediterranean','Greek','','German','American','','English','English',
'English','Spanish','American','Italian','','English','German','German','American','American','','American',
'American','Croatian','Welsh','American','American','English','American','English','French','Italian','English'
,'Italian','German','','Polish','Italian','French','','','','American','American','American','American','American',
'French','Spanish','French','Welsh','American','American','American','French','French','French','Mediterranean'
,'French','French','English','Italian','Jamaican','Brazilian','Mediterranean','Spanish','English','French','French'
,'French','MExican','French','Mediterranean','Swiss','American','American','French','Mexican','Swiss','American'
,'French','American','Canadian','French','Italian','Canadian','English','French','','','English',''
,'Canadian','Greek','Greek','French','French','English','French','Mediterranean','Jewish','French','','',
 'Mediterranean','Spanish','Mediterranean','','','','','','','Turkish','English','English','Italian',
'Italian','Jamaican','Jamaican','English','Welsh','French','Exotic','Italian','English','Italian','Italian'
,'Italian','','','French','Italian','','French','Italian','Italian','Belgian','','','','English','','Italian'
'Mediterranean','Swedish','Strange','Finish','Thai','Seafood','Seafood','Seafood','Strange','Mediterranean',
'Seafood','Italian','Seafood','English','Dessert','French','Salad','Salad','Salad','Dessert','Mediterranean'
'English','English','English','Turkish','Turkish','Turkish','English','Steak','French','Turkish','Seafood'
,'Mediterranean','Easy','Finnish','Baltic','Dessert','Dessert','Dessert','Dessert','Dessert','Dessert',
'Dessert','','Dessert','Indian','English','English','Dessert','Dessert','Dessert','Strange','Exotic',
'American dessert','American dessert','Dessert','Dessert','Dessert','Dessert','Dessert','Dessert','Dessert',
'Hard dessert','Dessert','French dessert','French dessert','American dessert','Dominican','Chinese','British',
'British','British','Bangladeshi','Chinese','British dessert','British dessert','British dessert',
'British dessert','Brisith dessert','Brisith dessert','Welsh','Welsh','French','BBq meat','BBq meat','BBq meat'
,'BBq meat','BBq meat','BBq meat','BBq meat','BBq meat','BBq meat','BBq fish','BBq meat','BBq seafood','BBq meat',
'BBq seafood','BBq','Irish','British','Indian','Dessert','Dessert','Philipin','Cereals','British','Italian'
,'Sauce','Italian','French','Mediterranean','Italian','English','Dessert','Basque','Basque','Basque','British'
,'British','French','British','British','German','Spanish','Mexican','Mediterranean','Mexican','Spanish',
'British','British','Italian','BBq meat','Indian','British','British','British','British','British','British'
,'British','British','British' ]

# %%
=['','','','','','','','','','','','','','','','','','','','']
# Out:
#   File "<ipython-input-136-520d98721c69>", line 1
#     =['','','','','','','','','','','','','','','','','','','','']
#     ^
# SyntaxError: invalid syntax

# %%
len(typefood2)
# Out:
# 600

# %%
typefood=[]
for i in range(0,db1.shape[0]):
    typefood.append('')

# %%
db1['type']=typefood
# Out:
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
db1['type'][0:len(typefood2)]=typefood2
# Out:
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/pandas/core/series.py:767: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._set_with(key, value)
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
db1['type'][600:600+len(typefood3)]=typefood3
# Out:
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/pandas/core/series.py:767: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._set_with(key, value)
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
db1
# Out:
#                                                       c  i  \
# 'Brandade'                                           30  0
# 'Dragon prawn' noodles                               30  1
# 'Firecracker' prawns                                 30  0
# 'Guilt-free gourmet' sticky toffee pudding           60  1
# 'Lion head' meatballs                                30  1
# 'Mr Carrot' on creamed carrot                        10  0
# 'Nduja sausage and sheeps’ cheese pizza              10  1
# 'No butter' brandy butter                           NaN  0
# 'Scampi', chips and tartare sauce                    30  0
# 'Skinnylicious' vanilla cake                        120  0
# 'Tex-Mex' chilli beans                               30  0
# 'Westie' shortbread                                  60  0
# 15 minute pasta                                      30  1
# 2-hour Christmas dinner                             120  1
# 3D biscuits                                         120  1
# ...

# %%
db1.shape
# Out:
# (820, 7)

# %%
numpy.block?
# Out:
# Object `numpy.block` not found.

# %%
np.block
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-313-a67a21213006> in <module>()
# ----> 1 np.block
#
# NameError: name 'np' is not defined

# %%
db2=db[10400:10450]

# %%
db2
# Out:
#                                                       c  i  \
# Wild mushroom bruschetta with poached eggs and ...   30  0
# Wild mushroom fricassée on toast with wilted ne...   10  0
# Wild mushroom pasta                                  30  0
# Wild mushroom pilaff                                 60  0
# Wild mushroom quiche with smoked salmon salad        60  0
# Wild mushroom risotto                                30  0
# Wild mushroom risotto balls with beef carpaccio      60  0
# Wild mushroom risotto with parmesan                  30  0
# Wild mushroom risotto with sautéed Jerusalem ar...   60  0
# Wild mushroom risotto with truffle oil               30  0
# Wild mushroom soup                                   30  1
# Wild mushroom soup with homemade garlic bread        60  0
# Wild mushroom tartlets                               60  0
# Wild mushrooms on crostini (funghi trifolati)        30  0
# Wild rabbit and morel stew with olive oil mash      120  0
# ...

# %%
# dictionary with mixed keys
my_dict = {'Italian': {'pizza','tortellini','frittata','pesto','penne','peperoni','burrata','pasta','spaghetti'
                      'mozzarella','biscotti','linguine','carpaccio','ricotta','Italian',' tagliolini','grissini',
                      'lasagna','ravioli','Lasagne','risotto','Linguine','Macaroni','macaroni','Pandoro',
                       'Panettone','Panna','Panzanella','pomodoro','arrabiatta','sarde','Pasta','pasta','pecorino'
                      'mascarpone','Penne','Pesto','Pizza','rosti','gnocchi','tiramisu','ragù','Ragù','Risotto',
                      'Ricotta','Saltimbocca','Sicilian','Spaghettini','pierogi','Tagliatelle','Taleggio',
                       'Prosecco','limoncello','zampone','Bresaola','Bruschetta','Caesar','Cannelloni',
                       'Cappuccino','Caponata','prosciutto','spaghetti','bolognese','tagliarini','panettone',
                      'Milanese','Parma'},
           'Vietnamese':{'Vietnamese'},
           'Mexican':{'chilli','burrito','fajitas','quesadillas','tacos','Chilled','Chilli'},
           'Pakistani':{'Tandori','Paneer','Shakshuka','kofte'},
           'British':{'Lancashire','pudding','Yorkshire','Hearty','Herring','mash','porridge','Malt','Stilton',
                     'rosemary','Leicester','Norfolk','Scouse','chowder','Simnel','Spatchcock','Sussex','hash',
                     'English'},
           'Chinese':{'Lapsang','Chinese','noodles','dumplings','Sichuan'},
           'Spanish':{'alioli','paella','Manchego','chorizo','Sangria','Spanish','chimichurri','Tortilla',
                      'gazpacho','padrón','Chorizo'},
           'Moroccan':{'couscous','tabbouleh','hummus','Kefta mkawra','tagine'},
           'Indian':{'Indian','bhaji','curry','kedgeree','Kashmiri biryani','Karara aloo chaat','Karelian hotpot',
                    'Kerala','Kofta','masala','dhansak','koftas','kachori','Punjabi','Rillons','kichri','Tarka',
                    'biryani','bhuna','pakoras','Brioche','tikka'},
          'French':{'Yule','brioche','soufflé','fondant','fondants','compôte','Provençal','gâteau','pâté',
                   'Macaroon','Macaroons','croûtons','pain','éclairs','Ratatouille','Savoy','quiche','papillote',
                   'casserole','mangetout','Gruyère','omelette','vichyssoise','sourdough','oysters','ratatouille',
                   'monsieur','Parmentier','fondue'},
           'German':{'schnitzel','German','sauerkraut','Schichttorte','tartare'},
           'Turkish':{'kebab','falafels','pitta','jaffa','ganoush','Pitta','shawarma'},
           'Vegan':{'tofu','Tofu','kale'},
           'Thai':{'Thai','chutney','Thai-style'},
           'Korean ':{'Korean '},
           'Hungarian':{'Kohlrabi'},
           'Latvian':{'Latvian'},
           'Dessert':{'cheesecake','cake','tart','Profiteroles','muffins','millefeuille','shortcake','Scones',
                      'Tarte','Toffee','brownies','Waffles','Brownies','tartlets','Caramelised','Catamel',
                      'caramel','cakes','meringues','biscuits','cookies','cookie','mousse','praline'},
           'American':{'Mac','pancakes','truffles','mini-muffins'},
           'Seafood':{'Mackerel'},
           'Malaysian':{'Malaysian','laksa'},
           'New Zealand':{'Pavlova','pavlova'},
           'Greek':{'Feta','feta','Moussaka','Spanakopita','Tzatziki'},
           'Russian':{'stroganoff','coulibiac','babka'},
           'Brazilian':{'Sao'},
           'Portuguese':{'Portuguese','Madeira'},
           'Swedish':{'Prinsesstårta'},
           'Cocktail':{'Mojito','mojito','vodka','Daiquiri','Martini'},
           'Ukranian':{'Kiev','Kievs','kiev'},
           'Peruvian':{'ceviche'},
           'Japanese':{'sushi','yuzu','yakitori','ramen','Wagyu','sashimi','Shiitake','Sushi','Teriyaki','Umami',
                      'tonkatsu'},
           'Argentinian':{'empanadas'},
           'Czech':{'goulash'},
           'Scotch':{'Scotch'},
           'Maldivian':{'kavaab'},
           'Singapore':{'Singapore'},
           'Smoked':{'Smoked'},
           'Welsh':{'Welsh'},
           'Irish':{'Irish'},
           'Cantonese':{'Cantonese'},
           'Mongolian':{'kulfi'},
           'Caribbean':{'Caribbean'},
           'Catalan':{'Catalan'},
           'Jewish':{'Cholent'}
          }

# %%
db3=db[1000:]
db3
# Out:
#                                                       c  i  \
# Brandy snaps with chilli and passion fruit cream     10  0
# Brandy snaps with ginger cream and chocolate         60  0
# Bread and butter pudding                             60  0
# Bread and butter pudding with caramel cream         120  0
# Bread and butter pudding with orange and cardamom   120  0
# Bread and butter pudding with papaya and saffron     60  0
# Bread and butter surprise                            30  0
# Bread and spinach soup                               10  0
# Bread pudding (Zemlovka)                             30  0
# Bread sauce                                          10  0
# Bread stuffed with sausage and zampone               60  0
# Breadcrumbed pheasant breast with beetroot puré...   60  0
# Breaded cheese                                       30  0
# Breaded chicken escalope, caper sauce, sautéed ...   30  0
# Breaded mushrooms with chilli and herb dip           10  0
# ...

# %%
given_string = "pizza"
given_string2 = "paella"

def get_food_origin(food_name):
    
    result = "Unknown"
    
    for k in my_dict.keys():
        #print("{} -> {}".format(k,my_dict[k]))
        if(food_name in my_dict[k])==True:
            result = k
            break
    return result

# %%
typefoodlist=[]
for i in range(0,db3.shape[0]):
    typefoodlist.append('')

# %%
db3['type']=typefoodlist
# Out:
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
db3
# Out:
#                                                       c  i  \
# Brandy snaps with chilli and passion fruit cream     10  0
# Brandy snaps with ginger cream and chocolate         60  0
# Bread and butter pudding                             60  0
# Bread and butter pudding with caramel cream         120  0
# Bread and butter pudding with orange and cardamom   120  0
# Bread and butter pudding with papaya and saffron     60  0
# Bread and butter surprise                            30  0
# Bread and spinach soup                               10  0
# Bread pudding (Zemlovka)                             30  0
# Bread sauce                                          10  0
# Bread stuffed with sausage and zampone               60  0
# Breadcrumbed pheasant breast with beetroot puré...   60  0
# Breaded cheese                                       30  0
# Breaded chicken escalope, caper sauce, sautéed ...   30  0
# Breaded mushrooms with chilli and herb dip           10  0
# ...

# %%
for i in range(0,db3.shape[0]):
    db3['type'][i]='Unknown'
    for word in db3.index[i].split():
        typefoodfood=get_food_origin(word)
        if typefoodfood!='Unknown':
            db3['type'][i]=str(typefoodfood)
            break
# Out:
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
db3[1150:1200]
# Out:
#                                                       c  i  \
# Christmas roast duck                                120  1
# Christmas rocky road                                 30  1
# Christmas seafood platter                            60  0
# Christmas tiramisu                                  NaN  1
# Christmas tree pavlova                              120  1
# Christmas trifle                                    120  1
# Christmas turkey crown and stuffing                 120  1
# Christmas veggie Wellington                          60  1
# Christmas wreath biscuits                            30  1
# Christmas-style zuccotto                            NaN  0
# Chunky apple crumble                                 60  1
# Chunky bacon and cucumber salad                      10  0
# Chunky banana bread                                  60  0
# Chunky celeriac soup                                 30  0
# Chunky cheese loaf                                   30  0
# ...

# %%
db3['l'][:1][0][0].split()
# Out:
# ['100g/4oz', 'unsalted', 'butter']

# %%
np.unique(db3['l']).shape
# Out:
# (9489,)

# %%
np.unique(db3['type'])
# Out:
# array(['American', 'Argentinian', 'Brazilian', 'British', 'Cantonese',
#        'Caribbean', 'Catalan', 'Chinese', 'Cocktail', 'Dessert', 'French',
#        'German', 'Greek', 'Hungarian', 'Indian', 'Irish', 'Italian',
#        'Japanese', 'Jewish', 'Latvian', 'Malaysian', 'Maldivian',
#        'Mexican', 'Mongolian', 'Moroccan', 'New Zealand', 'Pakistani',
#        'Peruvian', 'Portuguese', 'Russian', 'Scotch', 'Seafood',
#        'Singapore', 'Smoked', 'Spanish', 'Swedish', 'Thai', 'Turkish',
#        'Ukranian', 'Unknown', 'Vegan', 'Vietnamese', 'Welsh'], dtype=object)

# %%
from collections import Counter
Counter(db3['type'])
# Out:
# Counter({'American': 65,
#          'Argentinian': 2,
#          'Brazilian': 1,
#          'British': 476,
#          'Cantonese': 1,
#          'Caribbean': 4,
#          'Catalan': 2,
#          'Chinese': 86,
#          'Cocktail': 14,
#          'Dessert': 786,
#          'French': 350,
#          'German': 39,
#          'Greek': 39,
#          'Hungarian': 1,
#          'Indian': 207,
#          'Irish': 13,
#          'Italian': 680,
#          'Japanese': 40,
#          'Jewish': 1,
#          'Latvian': 2,
#          'Malaysian': 4,
#          'Maldivian': 1,
#          'Mexican': 293,
#          'Mongolian': 2,
#          'Moroccan': 93,
#          'New Zealand': 21,
#          'Pakistani': 6,
#          'Peruvian': 8,
#          'Portuguese': 17,
#          'Russian': 13,
#          'Scotch': 11,
#          'Seafood': 14,
#          'Singapore': 8,
#          'Smoked': 100,
#          'Spanish': 124,
#          'Swedish': 1,
#          'Thai': 173,
# ...

# %%
Counter(db3['type']=='Unknown')[1]
# Out:
# 5682

# %%
10490-Counter(db3['type']=='Unknown')[1]
# Out:
# 4808

# %%
my_dict.items()
my_dict.keys()
my_dict.values()
# Out:
# dict_values([{'tortelini', 'pizza', 'penne', 'pesto', 'burrata', 'peperoni', 'frittata'}, {'Vietnamese'}, {'burrito', 'chilli'}, {'pudding', 'Yorkshire'}, {'noodles'}, {'paella', 'alioli'}, {'curry', 'bhaji'}, {'Yule'}])

# %%
#given_string = "pizza"
#given_string2 = "paella"
#
#def get_food_origin(food_name):
#    
#    result = "Unknown"
#    
#    for k in my_dict.keys():
#        #print("{} -> {}".format(k,my_dict[k]))
#        if(my_dict[k] == food_name):
#            result = k
#            break
#    return result

# %%
import numpy as np
a=np.array([[0,1],[1,0]])

# %%
np.linalg.eig(a)
# Out:
# (array([ 1., -1.]), array([[ 0.70710678, -0.70710678],
#         [ 0.70710678,  0.70710678]]))

# %%
db3.groupby('type')['Italian']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-488-8bc9fd3d5162> in <module>()
# ----> 1 db3.groupby('type')['Italian']
#
# /Users/gerardmartinezcanelles/anaconda/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: Italian'

# %%
db4=db3[db3['type']=='Italian']

# %%
db4['l'][:2][1][3].split()
# Out:
# ['1', 'tbsp', 'olive', 'oil']
