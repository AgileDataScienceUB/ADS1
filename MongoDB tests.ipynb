# %%
import pandas as pd
import pymongo

# %%
class Users(object):
    def __init__(self, filename=None):
        try:
            conn=pymongo.MongoClient("mongodb://god:god@ds113938.mlab.com:13938/app")
            print ("Connected successfully!!!")
        except pymongo.errors.ConnectionFailure:
            print ("Could not connect to MongoDB: %s" % e )
        db = conn['app']
        self.collection = db.users
        if filename==None:
            self.users = pd.DataFrame(columns=['username','password','name','image','allergies'])
            for d in self.collection.find():
                self.users = self.users.append(pd.DataFrame.from_dict(d, orient='index').T,ignore_index=True)
        else:
            self.users = pd.read_json(filename).transpose()
            self.users = self.users.reset_index()
            print(self.users)
            self.users.columns = ['username','allergies','image','name','password']
            self.collection.insert_many(pd.DataFrame.to_dict(self.users,orient='records'))
        self.users = self.users.set_index('username')
    
    def getUsers(self):
        return self.users
    
    def getUser(self, username):
        return self.users[self.users['username']==username]
    
    def addUser(self, username, password, name = '', image = '', allergies = ''):
        if(username in self.users.username.unique()): return False
        aux = {'allergies': allergies, 'image': image, 'name': name, 'password': password, 'username':username}
        self.collection.insert_one(aux)
        self.users = self.users.append(pd.DataFrame.from_dict(aux, orient='index').T,ignore_index=True)
        return True
    
    def deleteUser(self, username):
        if(username not in self.users.username.unique()): return False
        self.collection.delete_one({"username":username})
        self.users = self.users[self.users['username'] != username]
        return True

# %%
Users('users2.json').getUsers()
# Out:
# Connected successfully!!!
#            index      allergies        image         name  \
# 0            "Be          ["Be]          "Be          "Be
# 1             "I           ["I]           "I           "I
# 2           "Let         ["Let]         "Let         "Let
# 3          "day"        ["day"]        "day"        "day"
# 4         "land"       ["land"]       "land"       "land"
# 5       "night."     ["night."]     "night."     "night."
# 6        "seas."      ["seas."]      "seas."      "seas."
# 7         "sky."       ["sky."]       "sky."       "sky."
# 8            1:1          [1:1]          1:1          1:1
# 9            And          [And]          And          And
# 10          Fill         [Fill]         Fill         Fill
# 11       Genesis      [Genesis]      Genesis      Genesis
# 12           God          [God]          God          God
# 13            He           [He]           He           He
# 14             I            [I]            I            I
# 15            In           [In]           In           In
# 16            It           [It]           It           It
# 17           Now          [Now]          Now          Now
# 18          Rule         [Rule]         Rule         Rule
# 19            So           [So]           So           So
# 20        Spirit       [Spirit]       Spirit       Spirit
# 21           The          [The]          The          The
# 22          Then         [Then]         Then         Then
# 23         There        [There]        There        There
# 24          They         [They]         They         They
# 25             a            [a]            a            a
# 26         above        [above]        above        above
# 27     according    [according]    according    according
# 28        across       [across]       across       across
# 29         after        [after]        after        after
# ..           ...            ...          ...          ...
# 193        them.        [them.]        them.        them.
# 194        there        [there]        there        there
# 195         they         [they]         they         they
# 196        thing        [thing]        thing        thing
# 197      things,     [things, ]      things,      things,
# 198        third        [third]        third        third
# 199           to           [to]           to           to
# 200         tree         [tree]         tree         tree
# 201        trees        [trees]        trees        trees
# 202          two          [two]          two          two
# 203        under        [under]        under        under
# 204           us           [us]           us           us
# 205   vegetation   [vegetation]   vegetation   vegetation
# 206  vegetation:  [vegetation:]  vegetation:  vegetation:
# 207         very         [very]         very         very
# 208          was          [was]          was          was
# 209        water        [water]        water        water
# 210       water.       [water.]       water.       water.
# 211       waters       [waters]       waters       waters
# 212       watery       [watery]       watery       watery
# 213        which        [which]        which        which
# 214         wild         [wild]         wild         wild
# 215         will         [will]         will         will
# 216       winged       [winged]       winged       winged
# 217         with         [with]         with         with
# 218      without      [without]      without      without
# 219       years,      [years, ]       years,       years,
# 220     yielding     [yielding]     yielding     yielding
# 221          you          [you]          you          you
# 222        yours        [yours]        yours        yours
#
#                                               password
# 0    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 1    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 2    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 3    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 4    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 5    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 6    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 7    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 8    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 9    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 10   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 11   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 12   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 13   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 14   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 15   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 16   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 17   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 18   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 19   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 20   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 21   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 22   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 23   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 24   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 25   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 26   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 27   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 28   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 29   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# ..                                                 ...
# 193  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 194  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 195  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 196  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 197  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 198  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 199  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 200  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 201  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 202  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 203  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 204  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 205  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 206  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 207  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 208  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 209  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 210  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 211  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 212  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 213  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 214  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 215  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 216  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 217  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 218  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 219  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 220  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 221  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 222  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
#
# [223 rows x 5 columns]
#                  allergies        image         name  \
# username
# "Be                  ["Be]          "Be          "Be
# "I                    ["I]           "I           "I
# "Let                ["Let]         "Let         "Let
# "day"              ["day"]        "day"        "day"
# "land"            ["land"]       "land"       "land"
# "night."        ["night."]     "night."     "night."
# "seas."          ["seas."]      "seas."      "seas."
# "sky."            ["sky."]       "sky."       "sky."
# 1:1                  [1:1]          1:1          1:1
# And                  [And]          And          And
# Fill                [Fill]         Fill         Fill
# Genesis          [Genesis]      Genesis      Genesis
# God                  [God]          God          God
# He                    [He]           He           He
# I                      [I]            I            I
# In                    [In]           In           In
# It                    [It]           It           It
# Now                  [Now]          Now          Now
# Rule                [Rule]         Rule         Rule
# So                    [So]           So           So
# Spirit            [Spirit]       Spirit       Spirit
# The                  [The]          The          The
# Then                [Then]         Then         Then
# There              [There]        There        There
# They                [They]         They         They
# a                      [a]            a            a
# above              [above]        above        above
# according      [according]    according    according
# across            [across]       across       across
# after              [after]        after        after
# ...                    ...          ...          ...
# them.              [them.]        them.        them.
# there              [there]        there        there
# they                [they]         they         they
# thing              [thing]        thing        thing
# things,         [things, ]      things,      things,
# third              [third]        third        third
# to                    [to]           to           to
# tree                [tree]         tree         tree
# trees              [trees]        trees        trees
# two                  [two]          two          two
# under              [under]        under        under
# us                    [us]           us           us
# vegetation    [vegetation]   vegetation   vegetation
# vegetation:  [vegetation:]  vegetation:  vegetation:
# very                [very]         very         very
# was                  [was]          was          was
# water              [water]        water        water
# water.            [water.]       water.       water.
# waters            [waters]       waters       waters
# watery            [watery]       watery       watery
# which              [which]        which        which
# wild                [wild]         wild         wild
# will                [will]         will         will
# winged            [winged]       winged       winged
# with                [with]         with         with
# without          [without]      without      without
# years,           [years, ]       years,       years,
# yielding        [yielding]     yielding     yielding
# you                  [you]          you          you
# yours              [yours]        yours        yours
#
#                                                       password
# username
# "Be          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# "I           f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# "Let         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# "day"        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# "land"       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# "night."     f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# "seas."      f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# "sky."       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# 1:1          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# And          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# Fill         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# Genesis      f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# God          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# He           f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# I            f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# In           f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# It           f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# Now          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# Rule         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# So           f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# Spirit       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# The          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# Then         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# There        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# They         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# a            f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# above        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# according    f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# across       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# after        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# ...                                                        ...
# them.        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# there        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# they         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# thing        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# things,      f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# third        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# to           f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# tree         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# trees        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# two          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# under        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# us           f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# vegetation   f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# vegetation:  f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# very         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# was          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# water        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# water.       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# waters       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# watery       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# which        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# wild         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# will         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# winged       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# with         f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# without      f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# years,       f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# yielding     f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# you          f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
# yours        f2598f4688f7f6e1ba301093c5c79cb31def9a567f1915...
#
# [223 rows x 4 columns]

# %%
class Recipes(object):
    def __init__(self, filename=None):
        try:
            conn=pymongo.MongoClient("mongodb://god:god@ds113938.mlab.com:13938/app")
            print ("Connected successfully!!!")
        except pymongo.errors.ConnectionFailure:
            print ("Could not connect to MongoDB: %s" % e )
        db = conn['app']
        self.collection = db.recipes
        if filename==None:
            self.recipes = pd.DataFrame(columns=['name','c','i','l','p','s','v'])
            for d in self.collection.find():
                self.recipes = self.recipes.append(pd.DataFrame.from_dict(d, orient='index').T,ignore_index=True)
        else:
            self.recipes = pd.read_json(path_or_buf=filename).T
            self.recipes = self.recipes.reset_index()
            self.recipes.columns = ['name','c','i','l','p','s','v']
            self.collection.insert_many(pd.DataFrame.to_dict(db,orient='records'))
        self.recipes = self.recipes.set_index('name')

    def getRecipes(self):
        return self.recipes
    
    def getRecipe(self, name):
        return self.recipes[self.recipes['name']==name]

# %%
class Ratings(object):
    def __init__(self, filename=None):
        try:
            conn=pymongo.MongoClient("mongodb://god:god@ds113938.mlab.com:13938/app")
            print ("Connected successfully!!!")
        except pymongo.errors.ConnectionFailure:
            print ("Could not connect to MongoDB: %s" % e )
        db = conn['app']
        self.collection = db.ratings
        if filename!=None:
            r = pd.read_csv(filename,index_col = 0)
            r = pd.DataFrame.to_dict(r.T)
            for k, v in list(r.items()):
                for k2, v2 in list(v.items()):
                    if v2 == 0: del v[k2]
            for k, v in list(r.items()):
                v['username'] = k
                self.collection.insert_one(v)
        self.ratings = pd.DataFrame()
        for d in self.collection.find():
            u = d['username']
            del d['username']
            del d['_id']
            self.ratings = self.ratings.append(pd.DataFrame.from_dict(dict([(u,d)])).T)
            self.ratings = self.ratings.fillna(0)
    def getRatings(self):
        return self.ratings
    
    def addRating(self, username, recipe, rating):
        self.collection.update_one({'username':username},{"$set":{recipe:rating}})
        self.ratings.at[username,recipe] = rating
        return True

# %%
Ratings('ratings.csv')
# Out:
# Connected successfully!!!
